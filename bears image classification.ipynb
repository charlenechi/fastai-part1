# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'black'
file = 'urls_black.txt'

# %%
path = Path('/Users/charlenechi/course-v3/nbs/dl1/data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:35<00:00]
#     </div>
# Error ﻿http://www.coastalalaskaadventures.com/wp-content/uploads/2017/01/larry-Weishuhn-alaska-black-bear.jpg No connection adapters were found for '﻿http://www.coastalalaskaadventures.com/wp-content/uploads/2017/01/larry-Weishuhn-alaska-black-bear.jpg'
# Error 	https://cdn0.wideopenspaces.com/wp-content/uploads/2017/05/bb-sas-630x339.png 'content-length'
# Error 	https://bloximages.newyork1.vip.townnews.com/jhnewsandguide.com/content/tncms/assets/v3/editorial/f/a1/fa15bb3b-15b9-5e16-8c36-af3e9a92cad3/5bbf9aaa048f0.image.jpg?resize=400%2C254 'content-length'
# Error 	https://bloximages.chicago2.vip.townnews.com/enewscourier.com/content/tncms/assets/v3/editorial/c/82/c82c3486-8ae5-11e8-8d1a-4f658519a43a/5b4fd3380cc3b.image.jpg?resize=1200%2C800 'content-length'

# %%
folder = 'teddy'
file = 'urls_teddy.txt'

# %%
path = Path('/Users/charlenechi/course-v3/nbs/dl1/data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:16<00:00]
#     </div>
# Error ﻿https://images-na.ssl-images-amazon.com/images/I/81XW32PHc8L._SL1500_.jpg No connection adapters were found for '﻿https://images-na.ssl-images-amazon.com/images/I/81XW32PHc8L._SL1500_.jpg'
# Error 	https://pixl.varagesale.com/http://s3.amazonaws.com/hopshop-image-store-production/134633702/83e6c7a4acdd16016a928716210d9ae1.jpg?_ver=large_uploader_thumbnail&w=640&h=640&fit=crop&s=586e111d09a647ce1956e750f7660b9f 'content-length'
# Error 	https://ng.jumia.is/tnOlG9YOIHExiV-SewnRlMAcU9o=/fit-in/500x500/filters:fill(white):sharpen(1 HTTPSConnectionPool(host='ng.jumia.is', port=443): Max retries exceeded with url: /tnOlG9YOIHExiV-SewnRlMAcU9o=/fit-in/500x500/filters:fill(white):sharpen(1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error 	https://ii1.pepperfry.com/media/catalog/product/n/o/494x544/novel-couple-teddy-bear-curtain-holder-7-inch--pink-cream-colour--novel-couple-teddy-bear-curtain-ho-01ssyu.jpg 'content-length'

# %%
folder = 'grizzly'
file = 'urls_grizzly.txt'

# %%
path = Path('/Users/charlenechi/course-v3/nbs/dl1/data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:12<00:00]
#     </div>
# Error ﻿http://www.backcountrychronicles.com/wp-content/uploads/grizzly-bear.jpg No connection adapters were found for '﻿http://www.backcountrychronicles.com/wp-content/uploads/grizzly-bear.jpg'
# Error 	https://www.telegraph.co.uk/content/dam/news/2017/09/29/TELEMMGLPICT000110812442_trans_NvBQzQNjv4BqJ4eGk7y7RkP9yV7bRNs2XsUWaPIL6EwXkM4pEaoLDQI.jpeg?imwidth=450 'content-length'
# Error 	https://bloximages.chicago2.vip.townnews.com/rexburgstandardjournal.com/content/tncms/assets/v3/editorial/e/b2/eb2adf98-834c-5379-912a-ea49f2d204f0/5b5a3f729af08.image.jpg?resize=1200%2C797 'content-length'
# Error 	https://bloximages.chicago2.vip.townnews.com/montanauntamed.com/content/tncms/assets/v3/editorial/8/2c/82cc48dc-22e9-5b09-8280-7e5f74526021/5b9962af29a53.image.jpg?resize=1200%2C800 'content-length'
# Error 	https://bloximages.newyork1.vip.townnews.com/swnewsmedia.com/content/tncms/assets/v3/editorial/a/1b/a1b8eb00-9989-5aa4-b641-f1e23ddb9b09/5b9ba8a0eee6f.image.jpg?resize=1200%2C800 'content-length'
# Error 	https://bloximages.chicago2.vip.townnews.com/trib.com/content/tncms/assets/v3/editorial/2/9e/29ed22e3-d697-5ca1-b4e4-ae04b0c4b881/5bd74094181ce.image.jpg?resize=400%2C288 'content-length'
# Error 	https://bloximages.newyork1.vip.townnews.com/swnewsmedia.com/content/tncms/assets/v3/editorial/4/43/4430a137-bece-5cea-a2f1-d246a616a5dc/5b9ba8a19d3b8.image.jpg?resize=1200%2C800 'content-length'
# Error 	http://mediad.publicbroadcasting.net/p/kufm/files/styles/x_large/public/201603/grizzly-bear_Nathan-Rupert-CC-BY-NC-ND_0.jpg 'content-length'
# Error 	https://www.critterbabies.com/wp-content/uploads/2014/01/baby-grizzly-bear-cubs.jpg 'content-length'
# Error 	http://mediad.publicbroadcasting.net/p/wpr/files/styles/x_large/public/201803/brown-bear-yellowstone-national-park-wyoming.jpg 'content-length'
# Error 	http://gephardtdaily.com/wp-content/uploads/2015/08/Grizzlybear55.jpg 'content-length'

# %%
folder = 'polar'
file = 'urls_polar.txt'

# %%
path = Path('/Users/charlenechi/course-v3/nbs/dl1/data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 01:30<00:00]
#     </div>
# Error ﻿https://www.aboutanimals.com/images/polar-bear-head-above-328x492.jpg?c14113 No connection adapters were found for '﻿https://www.aboutanimals.com/images/polar-bear-head-above-328x492.jpg?c14113'
# Error 	https://www.coca-colacompany.com/content/dam/journey/us/en/private/2013/12/coke604-604-337-361f8244.rendition.598.336.jpg 'content-length'
# Error 	https://www.ctvnews.ca/polopoly_fs/1.3845591.1521198873!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg 'content-length'
# Error 	https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2018%2F10%2Fpolar-bear-2.jpg%3Fw%3D450&w=700&c=sc&poi=face&q=85 'content-length'
# Error 	https://res.cloudinary.com/uktv/image/upload/b_rgb:000000 'content-length'
# Error 	https://i1.sndcdn.com/artworks-000049077207-oktoy4-t500x500.jpg 'content-length'
# Error 	https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2018%2F10%2Fpolar-bear-1.jpg&w=1100&c=sc&poi=face&q=85 'content-length'
# Error 	https://pixfeeds.com/images/37/558297/1280-558297-627066956.png HTTPSConnectionPool(host='pixfeeds.com', port=443): Max retries exceeded with url: /images/37/558297/1280-558297-627066956.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')])")))
# Error 	https://d2wvksc3i53c0p.cloudfront.net/media/catalog/product/optimized/e/8/e8f207d5b0f0efa625ef73f465a62e8d/p217957z.jpg 'content-length'
# Error 	https://polarbearfacts.net/wp-content/uploads/2017/10/polar-bear-10.jpg 'content-length'
# Error 	http://mediad.publicbroadcasting.net/p/michigan/files/styles/x_large/public/201803/Talini.png 'content-length'
# Error 	https://res.cloudinary.com/dk-find-out/image/upload/q_80 'content-length'
# Error 	https://www.rgo.ru/sites/default/files/styles/headimage/public/bm_0.jpg?itok=KwUVl0eI HTTPSConnectionPool(host='www.rgo.ru', port=443): Max retries exceeded with url: /sites/default/files/styles/headimage/public/bm_0.jpg?itok=KwUVl0eI (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a1af87080>: Failed to establish a new connection: [Errno 60] Operation timed out'))

# %%
folder = 'panda'
file = 'urls_panda.txt'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('/Users/charlenechi/course-v3/nbs/dl1/data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 05:13<00:00]
#     </div>
# Error ﻿https://desenio.com/bilder/artiklar/zoom/7867_1.jpg No connection adapters were found for '﻿https://desenio.com/bilder/artiklar/zoom/7867_1.jpg'
# Error 	https://imagesvc.timeincapp.com/v3/mm/image?url=https%3A%2F%2Fpeopledotcom.files.wordpress.com%2F2017%2F10%2Fpanda-bear.jpg%3Fw%3D2000&w=700&c=sc&poi=face&q=85 'content-length'
# Error 	https://dynaimage.cdn.cnn.com/cnn/w_768 'content-length'
# Error 	http://xdn001.medyatrendleri.com/images/2016-06-03/rare-giant-baby-panda-born-in-belgian-zoo-hailed-as-true-miracle-75d689be.jpg HTTPConnectionPool(host='xdn001.medyatrendleri.com', port=80): Max retries exceeded with url: /images/2016-06-03/rare-giant-baby-panda-born-in-belgian-zoo-hailed-as-true-miracle-75d689be.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1a1af55518>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error 	http://tibetnature.net/en/wp-content/uploads/2014/02/GIANT-PANDA.jpg 'content-length'
# Error 	https://wonderopolis.org/_img?img=/wp-content/uploads/2014/05/dreamstime_xl_30774508-custom.jpg&transform=resizeCrop 'content-length'
# Error 	https://cdn.searchenginejournal.com/wp-content/uploads/2017/11/google-panda-update-760x400.png 'content-length'
# Error 	https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1025158647612170 'content-length'
# Error 	https://multimedia.scmp.com/widgets/jia-jia/images/JiaJia.png HTTPSConnectionPool(host='multimedia.scmp.com', port=443): Max retries exceeded with url: /widgets/jia-jia/images/JiaJia.png (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a1af87b70>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Error 	https://www.macaupanda.org.mo/e/info/showImg.aspx/macaupanda-PandaPhotos-636631198769834.jpg HTTPSConnectionPool(host='www.macaupanda.org.mo', port=443): Max retries exceeded with url: /e/info/showImg.aspx/macaupanda-PandaPhotos-636631198769834.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a1af55828>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# Error 	https://ocs-pl.oktawave.com/v1/AUTH_e1d5d90a-20b9-49c9-a9cd-33fc2cb68df3/mrgugu-products/20170605141415_iiaTSl5qFYIzLyIw_1000-1000.jpg HTTPSConnectionPool(host='ocs-pl.oktawave.com', port=443): Max retries exceeded with url: /v1/AUTH_e1d5d90a-20b9-49c9-a9cd-33fc2cb68df3/mrgugu-products/20170605141415_iiaTSl5qFYIzLyIw_1000-1000.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a1af875f8>: Failed to establish a new connection: [Errno 60] Operation timed out'))

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['teddy','grizzly','black','polar','panda']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# teddy
#     <div>
#       <progress value='178' max='178', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [178/178 00:02<00:00]
#     </div>
# grizzly
#     <div>
#       <progress value='160' max='160', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [160/160 00:04<00:00]
#     </div>
# black
#     <div>
#       <progress value='175' max='175', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [175/175 00:04<00:00]
#     </div>
# polar
#     <div>
#       <progress value='189' max='189', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [189/189 00:05<00:00]
#     </div>
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000039.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000165.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/.DS_Store'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000028.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000098.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/urls_polar.txt'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000111.jpg'
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000054.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000121.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000042.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000178.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/polar/00000036.jpg'
# panda
#     <div>
#       <progress value='191' max='191', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [191/191 00:02<00:00]
#     </div>
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000006.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/.DS_Store'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000177.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000110.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000111.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000115.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000062.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000126.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000079.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000092.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000124.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000120.jpg'
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000080.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000081.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000019.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000150.jpg'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/urls_panda.txt'
# cannot identify image file '/Users/charlenechi/course-v3/nbs/dl1/data/bears/panda/00000034.jpg'

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=0).normalize(imagenet_stats)
# Out:
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:930: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +

# %%
data.classes
# Out:
# ['black', 'grizzly', 'models', 'panda', 'polar', 'teddy']

# %%
data.show_batch(rows=4, figsize=(8,10))

# %%
data.classes, data.c
# Out:
# (['black', 'grizzly', 'models', 'panda', 'polar', 'teddy'], 6)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 22:56
# epoch  train_loss  valid_loss  error_rate
# 1      1.188082    0.240483    0.072165    (05:39)
# 2      0.627621    0.126845    0.041237    (05:45)
# 3      0.417892    0.138244    0.051546    (05:46)
# 4      0.308236    0.133232    0.051546    (05:45)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
# Out:
# Total time: 13:02
# epoch  train_loss  valid_loss  error_rate
# 1      0.110951    0.134909    0.056701    (06:26)
# 2      0.106990    0.142268    0.051546    (06:35)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused(min_val=2)
# Out:
# [('black', 'grizzly', 3), ('grizzly', 'black', 3)]

# %%
interp.plot_top_losses(6)
